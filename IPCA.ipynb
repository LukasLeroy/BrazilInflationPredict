# %% [markdown]
# # Time Series Forecasting - Collecting Food Prices Online to Predict Inflation

# %% [markdown]
# Crawling Web Information Daily and Aggregating to create a time series and predict Brazilian Inflation Direction with Neural Networks (Long Short Term Memory Network)
#
# Project had participations of Alberto Cavallo of MIT Billion Prices Project and BTG Pactual Asset Management.

# %% [markdown]
# Objective:
#
#      Seek alternative data online, compare daily variation, weekly, 20 days, monthly with documented monthly inflation variation of each respective food item.
#
#      Choose specific food items that historically vary and have a minimum weight of 7% on the inflation measure.
#
#      These food items will be representative of a larger population or of a larger food category.
#
#      4 categories (Fruits, Legumes, Greens, Fish)
#
# Contacts:
#
#      MIT Billion Prices Project - Alberto Cavallo - acavallo@mit.edu
#
#      CEAGESP - Fabio Santos - fabio.santos@ceagesp.gov.br
#
# App:
#
#      2 Web Crawlers daily search food prices online at two main retailers at two main states in Brazil, Sao Paulo and Belo Horizonte.
#
#      The robots generate two csv/excel files that are daily complemented automatically with the most recent date at the top of the file.
#
#      Initial date of SP -  18/04/2017
#      Initial date of Minas Gerais - 28/07/2017
#
# Methodology
#
#       Estimatives - obtained from the calculation of the simple arithmetic mean of prices of the locations chosen, then compared in two consecutive months, resulting in a relative mean.
#
#       Agregating the relative means of the products through geometric mean, the variation of price of each subitem is obtained. This constitutes in the smallesest index aggregation that possesses explict ponderation.
#
#       After that, Laspeyres formula is applied, obtaining all the remaining aggregation levels of inflation structure: item, subgroup, group and finally, the general index for the region.
#
#       The national indexes are calculated after the regional indexes, utilizing a ponderated arithmetic mean.
#
#
# Flow
#
#       Crawler Python -> Agregation & Parsing in Python -> Export DataFrame Excel -> LSTM -> Visualization PowerBI

# %%
#necessary libraries

import time
import requests
from bs4 import BeautifulSoup
import csv
import datetime
import sys
import requests
import pandas as pd
import numpy as np
import lxml.html as lh

# %% [markdown]
# # Crawler Development

# %%
'''
Crawler 1 - Ceasa Minas
Gets daily information and exports it to csv 'CeasaMinas-daily.csv'

'''
global str
import time
import requests
from bs4 import BeautifulSoup
import csv
import datetime
import sys
import requests
import pandas as pd
import numpy as np
import lxml.html as lh 


def doit():

    urls = 'http://www.ceasaminas.com.br/precosgeral.asp'
    
    r = requests.get(urls) # If Response 405, 400 - verify = False

    response = r.content #.text
    
    if r.status_code != 200:
        sys.exit('Non 200 status code received')
        
        
    else:
        print('Success')

                       
    soup = BeautifulSoup(response, 'lxml')

    for a in soup.find_all('table', {'class':'full_table_list'} ):
        
        df_mg = pd.DataFrame([[td.text for td in row.find_all("td")] for row in a.select("tr")])
    
    df_mg
    
    #headers = [th.text.encode("utf-8") for th in a.select("tr td")]
    #svdata = datetime.datetime.now()
    #svstr = datetime.datetime.strftime(csvdata, '%d/%m/%Y')
    
    
    with open("DF_mg.csv", "a") as f:
        wr = csv.writer(f)
        wr.writerows([[td.text for td in row.find_all("td")] for row in a.select("tr")])

#if __name__ == "__main__":
 #   while True:
    
doit()
   #     time.sleep(115200)# a cada 32h
# Out:
# Success

# %%
'''
Crawler 2 - CEAGESP
Gets daily information and gets it to csv 'ceagesp-daily.csv'

''' 

def doit():

    base = datetime.datetime.today()

    ProductinList = ['frutas', 
                     'legumes',
                     'verduras',
                     'diversos',
                     'flores',
                     'pescados',] #pegar tudo
    numdays = 2

    DatainList = [(base - datetime.timedelta(days=x)) for x in range(0, numdays)]
    
    date_strings = [dt.strftime("%d/%m/%Y") for dt in DatainList]


    for i in date_strings:
        extracted_data = []
        item = i[0:2]+i[3:5]
        for j in ProductinList:
               url = 'http://www.ceagesp.gov.br/entrepostos/servicos/cotacoes/' 
               form_data = {
                       'cot_grupo': j,
                       'cot_data':  i,
                       'submit': 'submit',
                       }

               response = requests.post(url, data=form_data)
            
               if response.status_code != 200:
                   sys.exit('Non 200 status code received')
               
        
               tree = lh.document_fromstring(response.content)

               script = tree.xpath("//tr/*/text()") 
        
               row = tree.xpath("//td[1]//*/text()[1]")
        
               mergedlist = row + script 
        
               categoria = mergedlist[1:2]
               data =  mergedlist[3:4]
            
               produto =  mergedlist[6::7]
               preco =  mergedlist[10::7]
               classif = mergedlist[7::7]
               emb = mergedlist[8::7]
            
               finalResult = dict({'Data': data, 'Categoria': categoria,'Produto': produto, 'Preco': preco, 'Class': classif, 'Embalagens': emb })
        
            #   print(finalResult)
               extracted_data.append(finalResult)
               #extracted_data.append(cols)
    
        
    stuff = pd.DataFrame(extracted_data)


    s = pd.DataFrame({'Data':np.repeat(stuff.Data.values, stuff.Produto.str.len()),
                        'Produto':np.concatenate(stuff.Produto.values)})

    a =  pd.DataFrame({'Categoria':np.repeat(stuff.Categoria.values, stuff.Preco.str.len()),
                        'Preco':np.concatenate(stuff.Preco.values)})
 
    p =  pd.DataFrame({'Class':np.repeat(stuff.Preco.values, stuff.Class.str.len()),
                            'Class':np.concatenate(stuff.Class.values)})

    y = pd.DataFrame({'Embalagens':np.repeat(stuff.Embalagens.values, stuff.Embalagens.str.len()),
                            'Embalagens':np.concatenate(stuff.Embalagens.values)})
    
    final = pd.concat([s,a,p,y], axis = 1)
     
    print(final)
    
    final['Data'] = final['Data'].str[0] #datetime
    final['Categoria'] = final['Categoria'].str[0]

    #final.to_csv("semanagetmore2807{}.csv".format(item ))
        
    with open("DF_sp.csv", "a") as f:
        final.to_csv(f, header = False)
        
#if __name__ == "__main__":
 #   while True:
doit()
#        time.sleep(115200) # a cada 32h
# Out:
#               Data                          Produto    Categoria  Preco  \
# 0    [ 02/08/2017]                  ABACATE FORTUNA    [ FRUTAS]   4,63
# 1    [ 02/08/2017]                  ABACATE FORTUNA    [ FRUTAS]   4,23
# 2    [ 02/08/2017]                ABACATE MARGARIDA    [ FRUTAS]   3,66
# 3    [ 02/08/2017]                ABACATE MARGARIDA    [ FRUTAS]   3,33
# 4    [ 02/08/2017]                  ABACATE QUINTAL    [ FRUTAS]   4,65
# 5    [ 02/08/2017]                  ABACATE QUINTAL    [ FRUTAS]   4,25
# 6    [ 02/08/2017]                  ABACATE AVOCADO    [ FRUTAS]   5,88
# 7    [ 02/08/2017]                    ABACAXI HAVAI    [ FRUTAS]    3,7
# 8    [ 02/08/2017]                    ABACAXI HAVAI    [ FRUTAS]    3,1
# 9    [ 02/08/2017]                    ABACAXI HAVAI    [ FRUTAS]    2,5
# 10   [ 02/08/2017]                   ABACAXI PEROLA    [ FRUTAS]   3,79
# 11   [ 02/08/2017]                   ABACAXI PEROLA    [ FRUTAS]   3,29
# 12   [ 02/08/2017]                   ABACAXI PEROLA    [ FRUTAS]   2,95
# 13   [ 02/08/2017]                   ACEROLA FRESCA    [ FRUTAS]  13,01
# 14   [ 02/08/2017]                         ATEMOIA     [ FRUTAS]   7,26
# 15   [ 02/08/2017]                         ATEMOIA     [ FRUTAS]   6,13
# 16   [ 02/08/2017]                         ATEMOIA     [ FRUTAS]   4,99
# 17   [ 02/08/2017]  AMEIXA ESTRANG. ARGENTINA/CHILE    [ FRUTAS]   6,24
# 18   [ 02/08/2017]        AMEIXA ESTRANG. AMERICANA    [ FRUTAS]     20
# 19   [ 02/08/2017]                     BANANA TERRA    [ FRUTAS]   3,02
# 20   [ 02/08/2017]                      BANANA MACA    [ FRUTAS]   3,26
# 21   [ 02/08/2017]                      BANANA OURO    [ FRUTAS]    2,8
# 22   [ 02/08/2017]                  BANANA PRATA MG    [ FRUTAS]   2,57
# 23   [ 02/08/2017]                  BANANA PRATA SP    [ FRUTAS]   2,19
# 24   [ 02/08/2017]            BANANA NANICA CLIMAT.    [ FRUTAS]   1,58
# 25   [ 02/08/2017]                            CAJU     [ FRUTAS]  21,13
# 26   [ 02/08/2017]                            CAJU     [ FRUTAS]  18,76
# 27   [ 02/08/2017]                       CARAMBOLA     [ FRUTAS]   5,19
# 28   [ 02/08/2017]        CEREJA ESTRANG. AMERICANA    [ FRUTAS]   34,9
# 29   [ 02/08/2017]                      COCO VERDE     [ FRUTAS]    1,4
# ..             ...                              ...          ...    ...
# 393  [ 02/08/2017]                        LINGUADO   [ PESCADOS]     21
# 394  [ 02/08/2017]                        LINGUADO   [ PESCADOS]     11
# 395  [ 02/08/2017]                        LINGUADO   [ PESCADOS]      6
# 396  [ 02/08/2017]                      LULA FRESCA  [ PESCADOS]     40
# 397  [ 02/08/2017]                         MANJUBA   [ PESCADOS]     14
# 398  [ 02/08/2017]                        MEXILHAO   [ PESCADOS]     24
# 399  [ 02/08/2017]                         MISTURA   [ PESCADOS]    1,5
# 400  [ 02/08/2017]                          SALMAO   [ PESCADOS]     29
# 401  [ 02/08/2017]                           PARGO   [ PESCADOS]    9,5
# 402  [ 02/08/2017]                           PARGO   [ PESCADOS]    5,5
# 403  [ 02/08/2017]                           PARGO   [ PESCADOS]    2,5
# 404  [ 02/08/2017]                         PESCADA   [ PESCADOS]      9
# 405  [ 02/08/2017]                         PESCADA   [ PESCADOS]      7
# 406  [ 02/08/2017]                         PESCADA   [ PESCADOS]      5
# 407  [ 02/08/2017]                  PESCADA AMARELA  [ PESCADOS]     23
# 408  [ 02/08/2017]                    PESCADA GOETE  [ PESCADOS]    4,8
# 409  [ 02/08/2017]                    PESCADA GOETE  [ PESCADOS]    3,8
# 410  [ 02/08/2017]                    PESCADA GOETE  [ PESCADOS]    2,8
# 411  [ 02/08/2017]               PESCADA MARIA MOLE  [ PESCADOS]    4,8
# 412  [ 02/08/2017]               PESCADA MARIA MOLE  [ PESCADOS]    3,8
# 413  [ 02/08/2017]               PESCADA MARIA MOLE  [ PESCADOS]    2,8
# 414  [ 02/08/2017]                 PESCADA TORTINHA  [ PESCADOS]    3,3
# 415  [ 02/08/2017]                PINTADO CATIVEIRO  [ PESCADOS]   12,8
# 416  [ 02/08/2017]                          ROBALO   [ PESCADOS]     34
# 417  [ 02/08/2017]                  SARDINHA FRESCA  [ PESCADOS]    2,3
# 418  [ 02/08/2017]                  TRUTA CATIVEIRO  [ PESCADOS]     22
# 419  [ 02/08/2017]                        SOROROCA   [ PESCADOS]      9
# 420  [ 02/08/2017]                          TAINHA   [ PESCADOS]    7,5
# 421  [ 02/08/2017]                TILAPIA CATIVEIRO  [ PESCADOS]    6,3
# 422  [ 02/08/2017]                          TRAIRA   [ PESCADOS]    7,5
#
#                Class Embalagens
# 0    A BOCA 8 a 10         KG
# 1    B BOCA 11 e 12        KG
# 2    A BOCA 8 a 10         KG
# 3    B BOCA 11 e 12        KG
# 4    A BOCA 8 a 10         KG
# 5    B BOCA 11 e 12        KG
# 6    A                     KG
# 7    A GRAUDO              UND
# 8    B MEDIO               UND
# 9    C MIUDO               UND
# 10   A GRAUDO              UND
# 11   B MEDIO               UND
# 12   C MIUDO               UND
# 13                 -       KG
# 14   8/10 FRUTOS           KG
# 15   12 FRUTOS             KG
# 16   15 FRUTOS             KG
# 17                 -       KG
# 18                 -       KG
# 19                 -       KG
# 20                 -       KG
# 21                 -       KG
# 22                 -       KG
# 23                 -       KG
# 24                 -       KG
# 25   A                     KG
# 26   B                     KG
# 27                 -       KG
# 28                 -       KG
# 29                 -       UND
# ..               ...        ...
# 393  GRANDE                KG
# 394  MEDIO                 KG
# 395  PEQUENO               KG
# 396  PRIMEIRA              KG
# 397                -       KG
# 398  LIMPO                 KG
# 399                -       KG
# 400  GRANDE                KG
# 401  GRANDE                KG
# 402  MEDIO                 KG
# 403  PEQUENO               KG
# 404  GRANDE                KG
# 405  MEDIA                 KG
# 406  PEQUENA               KG
# 407                -       KG
# 408  GRANDE                KG
# 409  MEDIA                 KG
# 410  PEQUENA               KG
# 411  GRANDE                KG
# 412  MEDIA                 KG
# 413  PEQUENA               KG
# 414                -       KG
# 415                -       KG
# 416                -       KG
# 417  GRANDE                KG
# 418                -       KG
# 419                -       KG
# 420  GRANDE                KG
# 421                -       KG
# 422  MEDIO                 KG
#
# [423 rows x 6 columns]
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-262-0c613d35bf6b> in <module>()
#      91 #if __name__ == "__main__":
#      92  #   while True:
# ---> 93 doit()
#      94 #        time.sleep(115200) # a cada 32h
#
# <ipython-input-262-0c613d35bf6b> in doit()
#      87
#      88     with open("DF_sp.csv", "a") as f:
# ---> 89         final.to_csv(f),# header = False)
#      90
#      91 #if __name__ == "__main__":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1381                                      doublequote=doublequote,
#    1382                                      escapechar=escapechar, decimal=decimal)
# -> 1383         formatter.save()
#    1384
#    1385         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\formats\format.py in save(self)
#    1473                 self.writer = csv.writer(f, **writer_kwargs)
#    1474
# -> 1475             self._save()
#    1476
#    1477         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\formats\format.py in _save(self)
#    1574                 break
#    1575
# -> 1576             self._save_chunk(start_i, end_i)
#    1577
#    1578     def _save_chunk(self, start_i, end_i):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\formats\format.py in _save_chunk(self, start_i, end_i)
#    1600                                         quoting=self.quoting)
#    1601
# -> 1602         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#    1603
#    1604 # from collections import namedtuple
#
# pandas\lib.pyx in pandas.lib.write_csv_rows (pandas\lib.c:20752)()
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\x80' in position 47: character maps to <undefined>

# %% [markdown]
# # Data Preparation and Feauture Engineering

# %%
#Building DataFrame Final

#parsing df_sp

df_sp = pd.read_csv('testecsv2.csv',  encoding = "ISO-8859-1")

df_sp['Preco'] = df_sp['Preco'].str.replace(',', '.')

#print(df_sp['Data'])

#parsing mg

df_mg = pd.read_csv('testemg2.csv',  encoding = "ISO-8859-1")
df_mg = df_mg.iloc[:,0:4].replace('Grande BH', '')
df_mg = pd.melt(df_mg, id_vars=["Unnamed: 0", "Produtos", "Embalagens"], 
                  var_name="Data", value_name="Preco")
    
df_mg['Data'] = df_mg['Data'].map(lambda x: x.lstrip('Grande BH'))

df_mg['Produto'] = df_mg['Produtos']

del(df_mg['Unnamed: 0'],df_mg['Produtos'] )


frames  = [df_mg, df_sp]
df_all = pd.concat(frames, keys =['Data', 'Produto', 'Embalagens'] )


df_all = df_all.rename(columns = {'Unnamed: 0':'Estado'})
df_all = df_all.iloc[:,0:7].replace('NaN', 'MG')

df_all.set_index('Data', inplace=True)

df_all.to_csv('DF_all_prices.csv')
df_all
# Out:
#                                 Categoria            Class Embalagens  Preco  \
# Data
# 02/08/2017                            NaN              NaN         KG    3.3
# 02/08/2017                            NaN              NaN         KG   0.55
# 02/08/2017                            NaN              NaN         KG   1.66
# 02/08/2017                            NaN              NaN         KG      2
# 02/08/2017                            NaN              NaN         DZ     33
# 02/08/2017                            NaN              NaN         DZ      9
# 02/08/2017                            NaN              NaN         KG     14
# 02/08/2017                            NaN              NaN         KG   1.25
# 02/08/2017                            NaN              NaN         KG    1.4
# 02/08/2017                            NaN              NaN         KG      1
# 02/08/2017                            NaN              NaN         KG      2
# 02/08/2017                            NaN              NaN         KG      1
# 02/08/2017                            NaN              NaN         KG   1.31
# 02/08/2017                            NaN              NaN         DZ     20
# 02/08/2017                            NaN              NaN         KG    1.5
# 02/08/2017                            NaN              NaN         KG    1.1
# 02/08/2017                            NaN              NaN         KG   0.36
# 02/08/2017                            NaN              NaN         UN    1.2
# 02/08/2017                            NaN              NaN         DZ      9
# 02/08/2017                            NaN              NaN   06 UNID.     17
# 02/08/2017                            NaN              NaN         DZ     15
# 02/08/2017                            NaN              NaN         KG    3.3
# 02/08/2017                            NaN              NaN         KG   1.31
# 02/08/2017                            NaN              NaN         KG   2.33
# 02/08/2017                            NaN              NaN         KG      1
# 02/08/2017                            NaN              NaN         KG      3
# 02/08/2017                            NaN              NaN         KG   2.95
# 02/08/2017                            NaN              NaN         KG      1
# 02/08/2017                            NaN              NaN         KG    1.5
# 02/08/2017                            NaN              NaN         KG   1.25
# ...                                   ...              ...        ...    ...
#  02/08/2017                      VERDURAS  ESPECIAL              ENG    15.4
#  02/08/2017                      VERDURAS  PRIMEIRA              ENG   11.91
#  02/08/2017                      VERDURAS  EXTRA                 DZMC  18.19
#  02/08/2017                      VERDURAS  ESPECIAL              DZMC  15.19
#  02/08/2017                      VERDURAS  PRIMEIRA              DZMC  11.31
#  02/08/2017                      VERDURAS  EXTRA                 MC     9.56
#  02/08/2017                      VERDURAS                -       MC     3.52
#  02/08/2017                      VERDURAS                -       MC      3.5
#  02/08/2017                      VERDURAS  EXTRA                 KG      1.1
#  02/08/2017                      VERDURAS  ESPECIAL              KG     0.95
#  02/08/2017                      VERDURAS                -       BD     2.91
#  02/08/2017                      VERDURAS                -       PCT     4.7
#  02/08/2017                      VERDURAS                -       DZMC  15.51
#  02/08/2017                      VERDURAS  EXTRA                 MC     7.83
#  02/08/2017                      VERDURAS  ESPECIAL              MC     6.24
#  02/08/2017                      VERDURAS  PRIMEIRA              MC     4.78
#  02/08/2017                      VERDURAS                -       MC     3.41
#  02/08/2017                      VERDURAS                -       PC    11.14
#  02/08/2017                      VERDURAS  EXTRA                 DZMC  25.48
#  02/08/2017                      VERDURAS  ESPECIAL              DZMC  20.41
#  02/08/2017                      VERDURAS  PRIMEIRA              DZMC  15.96
#  02/08/2017                      VERDURAS  EXTRA                 ENG   23.86
#  02/08/2017                      VERDURAS                -       PCT    7.13
#  02/08/2017                      VERDURAS  EXTRA                 ENG   33.33
#  02/08/2017                      VERDURAS                -       PCT    5.06
#  02/08/2017                      VERDURAS                -       DZMC  20.87
#  02/08/2017                      VERDURAS                -       MC     8.94
#  02/08/2017                      VERDURAS  EXTRA                 DZMC   42.3
#  02/08/2017                      VERDURAS  ESPECIAL              DZMC  33.89
#  02/08/2017                      VERDURAS  PRIMEIRA              DZMC  25.55
#
#                                                                           Produto  \
# Data
# 02/08/2017                      ABACATE                                       ...
# 02/08/2017                      ABO. ITALIANA                                 ...
# 02/08/2017                      ABO. MENINA                                   ...
# 02/08/2017                      ABO. MOGANGA                                  ...
# 02/08/2017                      ABACAXI                                       ...
# 02/08/2017                      ALFACE                                        ...
# 02/08/2017                      ALHO BRASILEIRO                               ...
# 02/08/2017                      BANANA-NANICA                                 ...
# 02/08/2017                      BANANA-PRATA                                  ...
# 02/08/2017                      BATATA                                        ...
# 02/08/2017                      BATATA-DOCE                                   ...
# 02/08/2017                      BERINJELA                                     ...
# 02/08/2017                      BETERRABA                                     ...
# 02/08/2017                      BROCOLO                                       ...
# 02/08/2017                      CEBOLA                                        ...
# 02/08/2017                      CENOURA                                       ...
# 02/08/2017                      CHUCHU                                        ...
# 02/08/2017                      COCO VERDE                                    ...
# 02/08/2017                      COUVE                                         ...
# 02/08/2017                      COUVE-FLOR                                    ...
# 02/08/2017                      ESPINAFRE                                     ...
# 02/08/2017                      GOIABA                                        ...
# 02/08/2017                      INHAME                                        ...
# 02/08/2017                      JILO                                          ...
# 02/08/2017                      LARANJA                                       ...
# 02/08/2017                      LIMAO                                         ...
# 02/08/2017                      MACA                                          ...
# 02/08/2017                      MAMAO-FORMOSA                                 ...
# 02/08/2017                      MAMAO-HAVAI                                   ...
# 02/08/2017                      MANDIOCA                                      ...
# ...                                                                           ...
#  02/08/2017                                                             ESCAROLA
#  02/08/2017                                                             ESCAROLA
#  02/08/2017                                                            ESPINAFRE
#  02/08/2017                                                            ESPINAFRE
#  02/08/2017                                                            ESPINAFRE
#  02/08/2017                                                                 GOBO
#  02/08/2017                                                              HORTELA
#  02/08/2017                                                                LOURO
#  02/08/2017                                                          MILHO VERDE
#  02/08/2017                                                          MILHO VERDE
#  02/08/2017                                                          MILHO VERDE
#  02/08/2017                                                              MOIASHI
#  02/08/2017                                                             MOSTARDA
#  02/08/2017                                                                 NABO
#  02/08/2017                                                                 NABO
#  02/08/2017                                                                 NABO
#  02/08/2017                                                              OREGANO
#  02/08/2017                                                       PALMITO PUPUNHA
#  02/08/2017                                                             RABANETE
#  02/08/2017                                                             RABANETE
#  02/08/2017                                                             RABANETE
#  02/08/2017                                                          REPOLHO LISO
#  02/08/2017                                                      COGUMELO SHITAKE
#  02/08/2017                                                          REPOLHO ROXO
#  02/08/2017                                                        COGUMELO PARIS
#  02/08/2017                                                               RUCULA
#  02/08/2017                                                                SALSA
#  02/08/2017                                                   SALSAO BRANCO/VERDE
#  02/08/2017                                                   SALSAO BRANCO/VERDE
#  02/08/2017                                                   SALSAO BRANCO/VERDE
#
#                                Estado
# Data
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# 02/08/2017                         MG
# ...                               ...
#  02/08/2017                       297
#  02/08/2017                       298
#  02/08/2017                       299
#  02/08/2017                       300
#  02/08/2017                       301
#  02/08/2017                       302
#  02/08/2017                       303
#  02/08/2017                       304
#  02/08/2017                       305
#  02/08/2017                       306
#  02/08/2017                       307
#  02/08/2017                       308
#  02/08/2017                       309
#  02/08/2017                       310
#  02/08/2017                       311
#  02/08/2017                       312
#  02/08/2017                       313
#  02/08/2017                       314
#  02/08/2017                       315
#  02/08/2017                       316
#  02/08/2017                       317
#  02/08/2017                       318
#  02/08/2017                       319
#  02/08/2017                       320
#  02/08/2017                       321
#  02/08/2017                       322
#  02/08/2017                       323
#  02/08/2017                       324
#  02/08/2017                       325
#  02/08/2017                       326
#
# [375 rows x 6 columns]

# %%
#Including Weight and Inflation Variation 

from openpyxl import load_workbook
import pandas as pd

wb2 = load_workbook('C:\Crawlers Enforce\PRC_ipca.xlsx')

print(wb2.get_sheet_names())
var = wb2['Variação no mês - Brasil']
peso = wb2['Ponderação - Brasil']

df_var = pd.DataFrame(var.values)
df_peso = pd.DataFrame(peso.values)

df_peso = df_peso.rename(columns = {'1':'Produto'})
df_peso = pd.DataFrame(df_peso[1:174])

#df_peso concatenate with df_food

#check if df_food == df_var & df_var_else
df_peso
# Out:
# ['Variação no mês - Brasil', 'Ponderação - Brasil']
#       0   5 variable  value
# 0   NaN NaN        2    NaN
# 1   NaN NaN        2    NaN
# 2   NaN NaN        2    NaN
# 3   NaN NaN        2    NaN
# 4   NaN NaN        2    NaN
# 5   NaN NaN        2    NaN
# 6   NaN NaN        2    NaN
# 7   NaN NaN        2    NaN
# 8   NaN NaN        2    NaN
# 9   NaN NaN        2    NaN
# 10  NaN NaN        2    NaN
# 11  NaN NaN        2    NaN
# 12  NaN NaN        2    NaN
# 13  NaN NaN        2    NaN
# 14  NaN NaN        2    NaN
# 15  NaN NaN        2    NaN
# 16  NaN NaN        2    NaN
# 17  NaN NaN        2    NaN
# 18  NaN NaN        2    NaN
# 19  NaN NaN        2    NaN
# 20  NaN NaN        2    NaN
# 21  NaN NaN        2    NaN
# 22  NaN NaN        2    NaN
# 23  NaN NaN        2    NaN
# 24  NaN NaN        2    NaN
# 25  NaN NaN        2    NaN
# 26  NaN NaN        2    NaN
# 27  NaN NaN        2    NaN
# 28  NaN NaN        2    NaN
# 29  NaN NaN        2    NaN
# ..   ..  ..      ...    ...
# 143 NaN NaN        2    NaN
# 144 NaN NaN        2    NaN
# 145 NaN NaN        2    NaN
# 146 NaN NaN        2    NaN
# 147 NaN NaN        2    NaN
# 148 NaN NaN        2    NaN
# 149 NaN NaN        2    NaN
# 150 NaN NaN        2    NaN
# 151 NaN NaN        2    NaN
# 152 NaN NaN        2    NaN
# 153 NaN NaN        2    NaN
# 154 NaN NaN        2    NaN
# 155 NaN NaN        2    NaN
# 156 NaN NaN        2    NaN
# 157 NaN NaN        2    NaN
# 158 NaN NaN        2    NaN
# 159 NaN NaN        2    NaN
# 160 NaN NaN        2    NaN
# 161 NaN NaN        2    NaN
# 162 NaN NaN        2    NaN
# 163 NaN NaN        2    NaN
# 164 NaN NaN        2    NaN
# 165 NaN NaN        2    NaN
# 166 NaN NaN        2    NaN
# 167 NaN NaN        2    NaN
# 168 NaN NaN        2    NaN
# 169 NaN NaN        2    NaN
# 170 NaN NaN        2    NaN
# 171 NaN NaN        2    NaN
# 172 NaN NaN        2    NaN
#
# [173 rows x 4 columns]

# %%
#Applying LSTM Prediction
import pandas as pd

df_test = df_sp = pd.read_csv('/Users/owner/Desktop/BRA.csv')

df_test = df_test[['date','fullprice','category']]

from pandas import read_csv
from pandas import datetime
from matplotlib import pyplotdf_test[:5]
# Out:
#         date  fullprice  category
# 0  11-Oct-07       15.0        61
# 1  12-Oct-07       15.0        61
# 2  13-Oct-07       15.0        61
# 3  14-Oct-07       15.0        61
# 4  15-Oct-07       15.0        61

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import datetime 

datetime.datetime.strptime(df_test['date'], '%d-%b-%Y').strftime('%Y-%m-%d')
#df_test['date'] = df_test['date'].astype('datetime64[ns]')
df_test['date']
df_test['fullprice'].plot()
pyplot.show()
date_list[:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a6f68df7e1e6> in <module>()
#       4 import datetime
#       5
# ----> 6 datetime.datetime.strptime(df_test['date'], '%d-%b-%Y').strftime('%Y-%m-%d')
#       7 #df_test['date'] = df_test['date'].astype('datetime64[ns]')
#       8 df_test['date']
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
import datetime as dt

# split data into train and test

X = df_test.values
train, test = X[0:-12], X[-12:]

# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
# make prediction
    predictions.append(history[-1])
# observation
    history.append(test[i])
# report performance
train
#dt.datetime.strptime(test, '%d-%b-%Y').strftime('%Y-%m-%d')

rmse = sqrt(mean_squared_error(test, predictions))
#print('RMSE: %.3f' % rmse)
# line plot of observed vs predicted
#pyplot.plot(test)
#pyplot.plot(predictions)
#pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3b84b0d3626e> in <module>()
#      23 train
#      24 #dt.datetime.strptime(test, '%d-%b-%Y').strftime('%Y-%m-%d')
# ---> 25 rmse = sqrt(mean_squared_error(test, predictions))
#      26 #print('RMSE: %.3f' % rmse)
#      27 # line plot of observed vs predicted
#
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     229     """
#     230     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 231         y_true, y_pred, multioutput)
#     232     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     233                                weights=sample_weight)
#
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73     """
#      74     check_consistent_length(y_true, y_pred)
# ---> 75     y_true = check_array(y_true, ensure_2d=False)
#      76     y_pred = check_array(y_pred, ensure_2d=False)
#      77
#
# //anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     371                                       force_all_finite)
#     372     else:
# --> 373         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     374
#     375         if ensure_2d:
#
# ValueError: could not convert string to float: '14-Oct-10'
